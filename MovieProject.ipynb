# %%
# !pip install numpy
# !pip install Pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install geopandas
# Out:
# Requirement already satisfied: numpy in c:\users\mo\anaconda3\lib\site-packages (1.24.4)
# Requirement already satisfied: Pandas in c:\users\mo\anaconda3\lib\site-packages (1.3.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\mo\anaconda3\lib\site-packages (from Pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\mo\anaconda3\lib\site-packages (from Pandas) (1.24.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\mo\anaconda3\lib\site-packages (from Pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\mo\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->Pandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\mo\anaconda3\lib\site-packages (3.5.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\mo\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\mo\anaconda3\lib\site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\mo\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mo\anaconda3\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mo\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mo\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mo\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mo\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\mo\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in c:\users\mo\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\mo\anaconda3\lib\site-packages (from seaborn) (1.24.4)
# Requirement already satisfied: scipy>=1.0 in c:\users\mo\anaconda3\lib\site-packages (from seaborn) (1.9.1)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\mo\anaconda3\lib\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: pandas>=0.23 in c:\users\mo\anaconda3\lib\site-packages (from seaborn) (1.3.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mo\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mo\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mo\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mo\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\mo\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\mo\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mo\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\mo\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\mo\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: geopandas in c:\users\mo\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: pandas>=1.1.0 in c:\users\mo\anaconda3\lib\site-packages (from geopandas) (1.3.3)
# Requirement already satisfied: pyproj>=3.0.1 in c:\users\mo\anaconda3\lib\site-packages (from geopandas) (3.6.0)
# Requirement already satisfied: shapely>=1.7.1 in c:\users\mo\anaconda3\lib\site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: fiona>=1.8.19 in c:\users\mo\anaconda3\lib\site-packages (from geopandas) (1.9.4.post1)
# Requirement already satisfied: packaging in c:\users\mo\anaconda3\lib\site-packages (from geopandas) (21.3)
# Requirement already satisfied: importlib-metadata in c:\users\mo\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (4.11.3)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\mo\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: six in c:\users\mo\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: click~=8.0 in c:\users\mo\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in c:\users\mo\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\mo\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (21.4.0)
# Requirement already satisfied: certifi in c:\users\mo\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (2022.9.14)
# Requirement already satisfied: pytz>=2017.3 in c:\users\mo\anaconda3\lib\site-packages (from pandas>=1.1.0->geopandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\mo\anaconda3\lib\site-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\mo\anaconda3\lib\site-packages (from pandas>=1.1.0->geopandas) (1.24.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\mo\anaconda3\lib\site-packages (from packaging->geopandas) (3.0.9)
# Requirement already satisfied: colorama in c:\users\mo\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8.19->geopandas) (0.4.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\mo\anaconda3\lib\site-packages (from importlib-metadata->fiona>=1.8.19->geopandas) (3.8.0)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %%
df = pd.read_csv("A:\Materials\C_Data Science\python\python Projects\movies.csv")
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %%
# Lets see if there is any missing value
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round( pct_missing)))
# Out:
# name - 0%
# rating - 0%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 0%
# gross - 0%
# company - 0%
# runtime - 0%

# %%
# data types for our columns 
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
print ("Summery of the Numeruc Columns :")
df.describe()
# Out:
# Summery of the Numeruc Columns :
#               year        score         votes        budget         gross  \
# count  7668.000000  7665.000000  7.665000e+03  5.497000e+03  7.479000e+03
# mean   2000.405451     6.390411  8.810850e+04  3.558988e+07  7.850054e+07
# std      11.153508     0.968842  1.633238e+05  4.145730e+07  1.657251e+08
# min    1980.000000     1.900000  7.000000e+00  3.000000e+03  3.090000e+02
# 25%    1991.000000     5.800000  9.100000e+03  1.000000e+07  4.532056e+06
# 50%    2000.000000     6.500000  3.300000e+04  2.050000e+07  2.020576e+07
# 75%    2010.000000     7.100000  9.300000e+04  4.500000e+07  7.601669e+07
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  7664.000000
# mean    107.261613
# std      18.581247
# min      55.000000
# 25%      95.000000
# 50%     104.000000
# 75%     116.000000
# max     366.000000

# %%
# see the describtion of the catergorical columns in the dataframe

df.describe( include = 'object')
# Out:
#                  name rating   genre                           released  \
# count            7668   7591    7668                               7666
# unique           7512     12      19                               3414
# top     Nobody's Fool      R  Comedy  February 14, 1986 (United States)
# freq                3   3697    2245                                  9
#
#            director       writer          star        country  \
# count          7668         7665          7667           7665
# unique         2949         4535          2814             59
# top     Woody Allen  Woody Allen  Nicolas Cage  United States
# freq             38           37            43           5475
#
#                    company
# count                 7651
# unique                2385
# top     Universal Pictures
# freq                   377

# %%
#Know the Columns 
df.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime'],
#       dtype='object')

# %%
#checking for mising Values 
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
#Clean Data 

#fill the emtpy Cells in (Votes, budget, gross, rating, runtime )
x = df["votes"].mean()
y = df["gross"].mean()
f = df["runtime"].mean()
z = np.random.choice(["R", "PG", "NC-17", "PG-13", "Not Rated"])

df["votes"].fillna(x, inplace=True)
df["gross"].fillna(y, inplace=True)
df["runtime"].fillna(f, inplace=True)
df["rating"].fillna(z, inplace=True)

# %%
# Fill empty cells in "Budget" with random data from existing values
existing_budgets = df.dropna(subset=["budget"])["budget"]
df["budget"] = df["budget"].apply(lambda x: np.random.choice(existing_budgets) if pd.isnull(x) else x)

# %%
# delete the cells that can't be filled
df = df.dropna()

# %%
#checking dunplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
#checking duplicated data in the dataframe
df = df.drop_duplicates()

# %%
#checking for missing values 
df.isnull().sum()
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
# change the datatype for the (votes, budget, gross, rating) columns
df["votes"] = df["votes"].astype('int64')
df["budget"] = df["budget"].astype('int64')
df["gross"] = df["gross"].astype('int64')
df["runtime"] = df["runtime"].astype('int64')
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7659                                       I Am Fear  Not Rated     Horror
# 7660                                Aloha Surf Hotel         PG     Comedy
# 7664                                     Dream Round         PG     Comedy
# 7665                                   Saving Mbango         PG      Drama
# 7667                                       Tee em el         PG     Horror
#
#       year                          released  score    votes  \
# 0     1980     June 13, 1980 (United States)    8.4   927000
# 1     1980      July 2, 1980 (United States)    5.8    65000
# 2     1980     June 20, 1980 (United States)    8.7  1200000
# 3     1980      July 2, 1980 (United States)    7.7   221000
# 4     1980     July 25, 1980 (United States)    7.3   108000
# ...    ...                               ...    ...      ...
# 7659  2020     March 3, 2020 (United States)    3.4      447
# 7660  2020  November 5, 2020 (United States)    7.1       14
# 7664  2020  February 7, 2020 (United States)    4.7       36
# 7665  2020         April 27, 2020 (Cameroon)    5.7       29
# 7667  2020   August 19, 2020 (United States)    5.7        7
#
#                 director                   writer              star  \
# 0        Stanley Kubrick             Stephen King    Jack Nicholson
# 1         Randal Kleiser  Henry De Vere Stacpoole    Brooke Shields
# 2         Irvin Kershner           Leigh Brackett       Mark Hamill
# 3           Jim Abrahams             Jim Abrahams       Robert Hays
# 4           Harold Ramis       Brian Doyle-Murray       Chevy Chase
# ...                  ...                      ...               ...
# 7659       Kevin Shulman            Kevin Shulman    Kristina Klebe
# 7660  Stefan C. Schaefer       Stefan C. Schaefer       Augie Tulba
# 7664        Dusty Dukatz              Lisa Huston  Michael Saquella
# 7665        Nkanya Nkwai             Lynno Lovert      Onyama Laura
# 7667        Pereko Mosia             Pereko Mosia  Siyabonga Mabaso
#
#              country    budget      gross                    company  runtime
# 0     United Kingdom  19000000   46998772               Warner Bros.      146
# 1      United States   4500000   58853106          Columbia Pictures      104
# 2      United States  18000000  538375067                  Lucasfilm      124
# 3      United States   3500000   83453539         Paramount Pictures       88
# 4      United States   6000000   39846344             Orion Pictures       98
# ...              ...       ...        ...                        ...      ...
# 7659   United States  10000000      13266              Roxwell Films       87
# 7660   United States  14000000   78500541        Abominable Pictures       90
# 7664   United States   7000000   78500541  Cactus Blue Entertainment       90
# 7665   United States     58750   78500541           Embi Productions      107
# 7667    South Africa   6500000   78500541                PK 65 Films      102
#
# [7645 rows x 15 columns]

# %%
# Order our Data a little bit to organize it

df = df.sort_values('gross', ascending= False)
df = df.reset_index(drop = True)
df.head()
# Out:
#                                          name rating   genre  year  \
# 0                                      Avatar  PG-13  Action  2009
# 1                           Avengers: Endgame  PG-13  Action  2019
# 2                                     Titanic  PG-13   Drama  1997
# 3  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 4                      Avengers: Infinity War  PG-13  Action  2018
#
#                             released  score    votes       director  \
# 0  December 18, 2009 (United States)    7.8  1100000  James Cameron
# 1     April 26, 2019 (United States)    8.4   903000  Anthony Russo
# 2  December 19, 1997 (United States)    7.8  1100000  James Cameron
# 3  December 18, 2015 (United States)    7.8   876000    J.J. Abrams
# 4     April 27, 2018 (United States)    8.4   897000  Anthony Russo
#
#                writer               star        country     budget  \
# 0       James Cameron    Sam Worthington  United States  237000000
# 1  Christopher Markus  Robert Downey Jr.  United States  356000000
# 2       James Cameron  Leonardo DiCaprio  United States  200000000
# 3     Lawrence Kasdan       Daisy Ridley  United States  245000000
# 4  Christopher Markus  Robert Downey Jr.  United States  321000000
#
#         gross                company  runtime
# 0  2847246203  Twentieth Century Fox      162
# 1  2797501328         Marvel Studios      181
# 2  2201647264  Twentieth Century Fox      194
# 3  2069521700              Lucasfilm      138
# 4  2048359754         Marvel Studios      149

# %% [markdown]
# ### Correlations

# %%
# Correlation Matrix between all numeric columns

df.corr(method = 'pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097922  0.223123  0.224042  0.252334  0.119750
# score    0.097922  1.000000  0.409468  0.051726  0.182881  0.399922
# votes    0.223123  0.409468  1.000000  0.352311  0.628735  0.308901
# budget   0.224042  0.051726  0.352311  1.000000  0.596600  0.214695
# gross    0.252334  0.182881  0.628735  0.596600  1.000000  0.241296
# runtime  0.119750  0.399922  0.308901  0.214695  0.241296  1.000000

# %%
df.corr(method = 'kendall')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.067192  0.331788  0.164456  0.182270  0.096494
# score    0.067192  1.000000  0.300140 -0.001670  0.080177  0.283326
# votes    0.331788  0.300140  1.000000  0.239549  0.508750  0.196950
# budget   0.164456 -0.001670  0.239549  1.000000  0.331468  0.163921
# gross    0.182270  0.080177  0.508750  0.331468  1.000000  0.155668
# runtime  0.096494  0.283326  0.196950  0.163921  0.155668  1.000000

# %%
#scatter plot budget vs gross using matplotlib

plt.scatter(x = df["budget"], y = df["gross"])
plt.title("Budget VS Gross Eanring")
plt.xlabel("Budget for film")
plt.ylabel("Gross Eanring ")

plt.figure(figsize=(10, 8))
plt.show()

# %%
# plot budget Vs gross using seaborn

sns.regplot(x="budget", y="gross", data=df)

plt.title("Budget VS Gross Earnings")
plt.xlabel("Budget For Film")
plt.ylabel("Gross Earnings")

plt.figure(figsize=(10, 8))  
plt.show()

# %%
# plot budget Vs Score using seaborn

sns.regplot(x="budget", y="score", data=df)

plt.title("Budget VS Gross Earnings")
plt.xlabel("Budget For Film")
plt.ylabel("Gross Earnings")

plt.figure(figsize=(10, 8))  
plt.show()

# %% [markdown]
# ### Answer Quetions about the data

# %%
# 1. How Many Movies are in the data ?
num_movies = df['name'].nunique()
print("Number of movies:", num_movies)
# Out:
# Number of movies: 7490

# %%
# 2. What is the average score of the movies?

average_score = df["score"].mean()
print("Average Scores : ", round(average_score, 3))
# Out:
# Average Scores :  6.392

# %%
# 3. What is the highest grossing movie?

highest_gorssing_movie = df[df["gross"]== df["gross"].max()]["name"].iloc[0]
print("Highest Grossing Movies : ", highest_gorssing_movie)
# Out:
# Highest Grossing Movies :  Avatar

# %%
# 4. How many movies were released in the United States?

un_released_movies = df[df['country']=='United States']
num_un_released_movies = un_released_movies['name'].nunique()
print("Number movies released in the United States : ", num_un_released_movies)
# Out:
# Number movies released in the United States :  5381

# %%
# 5. What is the total budget for all the movies?

total_budget = df["budget"].sum()
print("Total budget:", round(total_budget/1000000000, 4), 'Billion Dollar')
# Out:
# Total budget: 273.1439 Billion Dollar

# %%
# 6. What is the most common genre among the movies?

most_common_genre = df["genre"].value_counts().idxmax()
print("Most Commmon Genre :", most_common_genre )
# Out:
# Most Commmon Genre : Comedy

# %%
# 9. What are the names of movies with a score above 8.0 and a runtime below 120 minutes?

high_score_short_runtime_movies = df[(df["score"] > 8.0) & (df["runtime"] < 120)]["name"].tolist()
print("Movies with score above 8.0 and runtime below 120 minutes:" )
for idx, movie in enumerate(high_score_short_runtime_movies, start=1):
    print(f"{idx}- {movie}")
# Out:
# Movies with score above 8.0 and runtime below 120 minutes:
# 1- The Lion King
# 2- Toy Story 3
# 3- Finding Nemo
# 4- Inside Out
# 5- Coco
# 6- Up
# 7- The Sixth Sense
# 8- Monsters, Inc.
# 9- WALL·E
# 10- How to Train Your Dragon
# 11- The Intouchables
# 12- Toy Story
# 13- Indiana Jones and the Raiders of the Lost Ark
# 14- 1917
# 15- Back to the Future
# 16- Spider-Man: Into the Spider-Verse
# 17- Your Name.
# 18- The Silence of the Lambs
# 19- Gran Torino
# 20- The Truman Show
# 21- Howl's Moving Castle
# 22- Life Is Beautiful
# 23- Kill Bill: Vol. 1
# 24- The Grand Budapest Hotel
# 25- Three Billboards Outside Ebbing, Missouri
# 26- Pan's Labyrinth
# 27- Snatch
# 28- Close-Up
# 29- Eternal Sunshine of the Spotless Mind
# 30- Fargo
# 31- Stand by Me
# 32- Whiplash
# 33- The Big Lebowski
# 34- Full Metal Jacket
# 35- Blade Runner
# 36- Memento
# 37- Room
# 38- The Princess Bride
# 39- My Neighbor Totoro
# 40- American History X
# 41- The Usual Suspects
# 42- The Thing
# 43- Léon: The Professional
# 44- Trainspotting
# 45- Before Sunset
# 46- The Hunt
# 47- In the Mood for Love
# 48- Nausicaä of the Valley of the Wind
# 49- Requiem for a Dream
# 50- Before Sunrise
# 51- Song of the Sea
# 52- Lock, Stock and Two Smoking Barrels
# 53- Three Colors: Red
# 54- Reservoir Dogs
# 55- The Color of Paradise
# 56- The Celebration
# 57- Chungking Express
# 58- Children of Heaven
# 59- La Haine

# %% [markdown]
# ### Visualisations for the Data

# %%
# Set up the style for Seaborn
sns.set(style="whitegrid")

# Distribution of Ratings
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=df, x="rating")
plt.xlabel("Rating")
plt.ylabel("Count")
plt.title("Distribution of Ratings")

# Adding annotations on top of the bars
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')
plt.show()

# %%
# Average Score by Genre with Annotations

plt.figure(figsize=(12, 6))
ax = sns.barplot(data=df, x="genre", y="score")
plt.xticks(rotation=45)
plt.xlabel("Genre")
plt.ylabel("Average Score")
plt.title("Average Score by Genre")

plt.show()

# %%
#Scatter plot of score and gross Earnings 

plt.figure(figsize = (10, 6))
sns.scatterplot(data = df, x = "score", y = "gross", color = "r")
plt.xlabel("Score")
plt.ylabel(" Gross Earning")
plt.title("Scatter Plot of Score and Gross Earning")
plt.show()

# %%
# Histogram of Movie Runtime 
plt.figure(figsize=(10, 6))
ax = sns.histplot(data = df, x="runtime", bins = 25)
plt.xlabel("Runtime")
plt.ylabel("Frequency")
plt.title("Histogram of Movie Runtime")

# Adding annotations on top of the bars
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')
plt.show()

# %%
# Count of Movies by Country

plt.figure(figsize = (12, 6))
ax = sns.countplot(data = df, x="country", order= df["country"].value_counts().index)

plt.xticks(rotation=90)
plt.xlabel("Country")
plt.ylabel("Count")
plt.title("Count of Movies by Country")
plt.show()

# %%
# Line Plot of Gross Earnings Over Years

plt.figure(figsize=(12, 6))
df["year"] = df["year"].astype(int)
sns.lineplot(data=df, x="year", y="gross")
plt.xlabel("Year")
plt.ylabel("Gross Earnings")
plt.title("Gross Earnings Over Years")
plt.xticks(rotation=30)
plt.show()

# %%
# Barplot of Budget by Year

plt.figure(figsize=(12, 6))
ax = sns.barplot(data=df, x="year", y="budget",)
plt.xlabel("Year")
plt.ylabel("Average Budget")
plt.title("Average Budget by Year")
plt.xticks(rotation=45)
plt.show()

# %%
# Count of Movies by Director

plt.figure(figsize=(12, 6))
director_counts = df["director"].value_counts().head(10)
ax = sns.barplot(x=director_counts.index, y=director_counts.values)
plt.xlabel("Director")
plt.ylabel("Count")
plt.title("Count of Movies by Director (Top 10)")
plt.xticks(rotation=45)

# Adding annotations on top of the bars
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')
plt.show()
